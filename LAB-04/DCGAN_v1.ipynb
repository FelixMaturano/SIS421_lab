# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils

# Configuración del dispositivo (Usa la GPU si tienes CUDA disponible)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo a utilizar: {device}")
# Out:
# Dispositivo a utilizar: cuda:0

# %%
# ── RUTA A TU DATASET ──
# Apunta a la carpeta principal que contiene la subcarpeta 'imagenes'
ruta_dataset = r'D:\2026\IA-2026-DATASETS\NUEVO_DATASET'

# Transformaciones para la DCGAN: Redimensionar, recortar, convertir a tensor y normalizar
transformaciones = transforms.Compose([
    transforms.Resize(64),
    transforms.CenterCrop(64),
    transforms.RandomHorizontalFlip(p=0.5), # Aumento de datos para mejorar el aprendizaje
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # Normalización para 3 canales (RGB)
])

# Cargamos el dataset con ImageFolder
dataset = dset.ImageFolder(root=ruta_dataset, transform=transformaciones)

# DataLoader
batch_size = 64
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

print(f"¡Éxito! Se cargaron {len(dataset)} imágenes listas para entrenar.")
# Out:
# ¡Éxito! Se cargaron 809 imágenes listas para entrenar.
